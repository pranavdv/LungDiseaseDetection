# %% [markdown]
# # Purpose
# This notebook will be used as a tutorial for understanding the steps, formating and other details for the lung disease detection project. You'll notice that this notebook has been split up into multiple sections; this is to make things easier to read, reuse and navigate. You can use the headings of next sections in an actual notebook as is.

# %% [markdown]
# # Step 5
# **Evaluate the model**
#
# The main tasks that have to be performed in this step are:
# - Use tensorboard to visualize learning curves for metrics like loss, accuracy, precision and recall over training and validation data. Use this [link](https://www.tensorflow.org/tensorboard/get_started) to learn more about this. You've already created a tensorflow callback in tutorial_3 and trained the model with it. All that's left to do is fire it up.
#
# - Create a test generator. This step is similar to making train and validation generators except that you don't add any augmentation. Make sure you still rescale the image.
#
# - Evaluate the model on the test set. Print the metric names and their corresponding values returned (metrics are loss, accuracy, precision and recall). Use this [link](https://www.tensorflow.org/api_docs/python/tf/keras/Model#evaluate) to learn more.
#
# - Make predictions on the test set. If you used the sequential API, "predict_classes" method should work for this. Otherwise use "predict" and convert the probabilities to classes by setting a threshold.
#
# - Print [classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html) using scikit learn.
#
# - Get [confusion matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) and create a [graph](https://seaborn.pydata.org/generated/seaborn.heatmap) for it.
#
# - Plot [ROC curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
